# %% [markdown]
# <H1> Python Kickstart</H1>

# %%
print("Hello World");
print('Single Quote Hello World!');
# Out:
# Hello World
# Single Quote Hello World!

# %%
print("Sum =",2+3)
# Out:
# Sum = 5

# %%
print('this','is','the','first class')
# Out:
# this is the first class

# %%
print("Line1");
print("Line2");
# Out:
# Line1
# Line2

# %%
print("Line", end=" ")
print("Line2");
# Out:
# Line Line2

# %%
print("Line", end="###")
print("Line2")
# Out:
# Line###Line2

# %%
year=input("Enter your Birth Year")
# Out:
# Enter your Birth Year 1945

# %%
print(year);
# Out:
# 1945

# %%
import datetime
print(type(year))
int(datetime.datetime.now().year)
# Out:
# <class 'str'>
# 2024

# %%
import datetime
#age=input("Enter your age:")
#age=int(age)+10
print("You will be",datetime.datetime.now().year - (int(year))+10,"after 10 years")
# Out:
# You will be 52 after 10 years

# %%
#This is a comment

# %%
"""This is Documentation for this function...will not be printed"""
2+5
# Out:
# 7

# %%
print(2+5)
"""This is Documentation for this function... Will be printed"""
# Out:
# 7
# 'This is Documentation for this function... Will be printed'

# %%
print("@"*100)
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %% [markdown]
# <H1> Modules </H1>

# %%
import sys

# %%
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# import math

# %%
# %config Completer.use_jedi = False

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
type(math.sqrt(36))
# Out:
# float

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
1
# Out:
# 1

# %%
type(1)
# Out:
# int

# %%
type(3.4)
# Out:
# float

# %%
z=2+5j

# %%
z.imag
# Out:
# 5.0

# %%
z.real
# Out:
# 2.0

# %%
complex(2,5)
# Out:
# (2+5j)

# %%
pow(2,10)
# Out:
# 1024

# %%
type(z.real)
# Out:
# float

# %%
int(2.4)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0
