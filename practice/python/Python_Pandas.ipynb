# %% [markdown]
# <H1> Data Exploration using Pandas</H1>

# %% [markdown]
# Task:
#     - Import the dataset
#     - Clean, format, describe
#     - Grouping/merging
#     - Export the results

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <b>Import my dataset</b>
